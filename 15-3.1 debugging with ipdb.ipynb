# %%
# debugging with ipdb
# author: Gressling, T
# license: MIT License # code: github.com/gressling/examples
# activity: single example # index: 15-3

# %%
# !pip install ipdb

# %%
import ipdb
ipdb.set_trace()
ipdb.set_trace(context=5) # will show five lines of code

# analyseSubStructure.get_mol(mol)

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON
