# %%
# intake example
# author: Gressling, T
# license: MIT License # code: github.com/gressling/examples
# activity: single example # index: 15-2

# %%
# !pip install intake

# %%
# !intake example

# %%
import intake
catalog = intake.open_catalog('us_states.yml')
dataset = intake.open_csv('states_*.csv')

# %%
dataset
# Out:
# csv:
#   args:
#     urlpath: states_*.csv
#   description: ''
#   driver: intake.source.csv.CSVSource
#   metadata: {}

# %%
catalog
# Out:
# us_states:
#   args:
#     path: us_states.yml
#   description: ''
#   driver: intake.catalog.local.YAMLFileCatalog
#   metadata: {}
