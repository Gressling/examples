# %%
# Jupyter Notebook for retrieving from REST APIs
# author: Gressling, T
# license: MIT License # code: github.com/gressling/examples
# activity: Single example # index: 8-2

# %%
import requests
api_url = 'http://127.0.0.1:8081/predict'

# %%
data = {'name': 'reaction1', 'molecules': ['COCc1cc(C=O)ccc1O', 'CN=C=O']}

r = requests.post(api_url + '/APIv1', \
                  headers={'Authorization': 'token %s' % <API KEY>,}, \
                  json=data)

# %%
r.raise_for_status()
r.json()
