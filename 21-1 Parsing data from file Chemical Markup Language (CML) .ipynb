# %%
# Parsing data from file Chemical Markup Language (CML)
# author: Gressling, T
# license: MIT License # code: github.com/gressling/examples
# activity: single example # index: 21-1

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('Spectral_DataSet.xml')
root = tree.getroot()

# %%
# query elements
print(root.tag)

# %%
# query elements
for xlist in root.findall('XLIST'):
 dictName = xlist.get('DICTNAME')
 print(name)
