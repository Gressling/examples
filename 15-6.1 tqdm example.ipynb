# %%
# tqdm progress bar example
# author: Gressling, T
# license: MIT License # code: github.com/gressling/examples
# activity: single example # index: 15-6

# %%
from tqdm import tqdm
import time

max_atoms=10000
for i in tqdm(range(max_atoms)):
  time.sleep(.01)
# Out:
#  13%|█▎        | 1260/10000 [00:12<01:29, 97.78it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a74e7899df17> in <module>()
#       4 max_atoms=10000
#       5 for i in tqdm(range(max_atoms)):
# ----> 6   time.sleep(.01)
#
# KeyboardInterrupt:
