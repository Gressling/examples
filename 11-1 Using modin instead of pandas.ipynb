# %%
# Using modin instead of pandas
# author: Gressling, T
# license: MIT License # code: github.com/gressling/examples
# activity: single example # index: 11-1

# %%
# !pip install modin[ray] # or dask

# %%
import ray
ray.init(num_cpus=4) # limit cpus
import pandas as pd
pdf = pd.read_csv("molecules.csv") # classic pandas

# %%
import modin.pandas as pd
mdf = pd.read_csv("molecules.csv") # distributes among the 4 cpus
